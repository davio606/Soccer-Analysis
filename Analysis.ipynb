# %%
import os
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Passing Stats.csv")

# %%
headers=data.iloc[0]
clean_data= pd.DataFrame(data.values[1:], columns=headers)
clean_data.head()
# Out:
# 0               Player  Nation   Pos           Squad                Comp  \
# 0  Patrick van Aanholt  nl NED    DF  Crystal Palace  eng Premier League
# 1          Issah Abbas  gh GHA    FW        Mainz 05       de Bundesliga
# 2     Yunis Abdelhamid  ma MAR    DF           Reims          fr Ligue 1
# 3          Mehdi Abeid  dz ALG  MFDF          Nantes          fr Ligue 1
# 4      Laurent Abergel  fr FRA    MF         Lorient          fr Ligue 1
#
# 0     Age  Born  90s   Cmp   Att  ...  Cmp% Ast    xA   A-xA    KP   1/3  \
# 0  30-089  1990  3.2  45.6  56.3  ...    60   0  0.06  -0.06  0.63  3.75
# 1  22-061  1998    0     2     2  ...   100   0     0      0     0     0
# 2  33-059  1987   10  47.6  53.6  ...    75   0     0      0     0   2.5
# 3  28-112  1992  6.9  40.3  49.1  ...  66.3   0  0.07  -0.07   1.3  4.64
# 4  27-299  1993   10  41.4  49.5  ...  71.8   0  0.02  -0.02   0.2   3.3
#
# 0   PPA CrsPA PrgDist Car  Prog
# 0  1.88  0.31       135.3  6.56
# ...

# %%
clean_data.head()
# Out:
# 0               Player  Nation   Pos           Squad                Comp  \
# 0  Patrick van Aanholt  nl NED    DF  Crystal Palace  eng Premier League
# 1          Issah Abbas  gh GHA    FW        Mainz 05       de Bundesliga
# 2     Yunis Abdelhamid  ma MAR    DF           Reims          fr Ligue 1
# 3          Mehdi Abeid  dz ALG  MFDF          Nantes          fr Ligue 1
# 4      Laurent Abergel  fr FRA    MF         Lorient          fr Ligue 1
#
# 0     Age  Born  90s   Cmp   Att  ...  Cmp% Ast    xA   A-xA    KP   1/3  \
# 0  30-089  1990  3.2  45.6  56.3  ...    60   0  0.06  -0.06  0.63  3.75
# 1  22-061  1998    0     2     2  ...   100   0     0      0     0     0
# 2  33-059  1987   10  47.6  53.6  ...    75   0     0      0     0   2.5
# 3  28-112  1992  6.9  40.3  49.1  ...  66.3   0  0.07  -0.07   1.3  4.64
# 4  27-299  1993   10  41.4  49.5  ...  71.8   0  0.02  -0.02   0.2   3.3
#
# 0   PPA CrsPA PrgDist Car  Prog
# 0  1.88  0.31       135.3  6.56
# ...

# %%
prem = clean_data.loc[clean_data['Comp'] == 'eng Premier League']
prem
# Out:
# 0                         Player   Nation   Pos            Squad  \
# 0            Patrick van Aanholt   nl NED    DF   Crystal Palace
# 7                  Tammy Abraham  eng ENG    FW          Chelsea
# 13                     Che Adams  eng ENG    FW      Southampton
# 16              Tosin Adarabioyo  eng ENG    DF           Fulham
# 19                        Adrián   es ESP    GK        Liverpool
# 25                 Sergio Agüero   ar ARG    FW  Manchester City
# 31                      Ola Aina   ng NGA    DF           Fulham
# 33               Rayan Aït Nouri   fr FRA    DF           Wolves
# 34                    Semi Ajayi   ng NGA    DF        West Brom
# 39                    Nathan Aké   nl NED    DF  Manchester City
# 49               Marc Albrighton  eng ENG  DFMF   Leicester City
# 52              Thiago Alcántara   es ESP    MF        Liverpool
# 55             Toby Alderweireld   be BEL    DF        Tottenham
# ...

# %%
prem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428 entries, 0 to 2300
# Data columns (total 31 columns):
# Player         428 non-null object
# Nation         428 non-null object
# Pos            428 non-null object
# Squad          428 non-null object
# Comp           428 non-null object
# Age            426 non-null object
# Born           426 non-null object
# 90s            428 non-null object
# Cmp            428 non-null object
# Att            428 non-null object
# Cmp%           428 non-null object
# TotDist        428 non-null object
# PrgDist        428 non-null object
# Cmp            428 non-null object
# Att            428 non-null object
# Cmp%           424 non-null object
# Cmp            428 non-null object
# Att            428 non-null object
# Cmp%           420 non-null object
# Cmp            428 non-null object
# Att            428 non-null object
# Cmp%           406 non-null object
# Ast            428 non-null object
# xA             428 non-null object
# ...
