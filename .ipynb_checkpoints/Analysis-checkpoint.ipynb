# %%
import os
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Passing Stats.csv")

# %%
headers=data.iloc[0]
clean_data= pd.DataFrame(df.values[1:], columns=headers)
clean_data.head()
# Out:
# 0               Player  Nation   Pos           Squad                Comp  \
# 0  Patrick van Aanholt  nl NED    DF  Crystal Palace  eng Premier League
# 1          Issah Abbas  gh GHA    FW        Mainz 05       de Bundesliga
# 2     Yunis Abdelhamid  ma MAR    DF           Reims          fr Ligue 1
# 3          Mehdi Abeid  dz ALG  MFDF          Nantes          fr Ligue 1
# 4      Laurent Abergel  fr FRA    MF         Lorient          fr Ligue 1
#
# 0     Age  Born  90s   Cmp   Att  ...  Cmp% Ast    xA   A-xA    KP   1/3  \
# 0  30-089  1990  3.2  45.6  56.3  ...    60   0  0.06  -0.06  0.63  3.75
# 1  22-061  1998    0     2     2  ...   100   0     0      0     0     0
# 2  33-059  1987   10  47.6  53.6  ...    75   0     0      0     0   2.5
# 3  28-112  1992  6.9  40.3  49.1  ...  66.3   0  0.07  -0.07   1.3  4.64
# 4  27-299  1993   10  41.4  49.5  ...  71.8   0  0.02  -0.02   0.2   3.3
#
# 0   PPA CrsPA PrgDist Car  Prog
# 0  1.88  0.31       135.3  6.56
# ...

# %%
clean_data.head()
# Out:
# 0               Player  Nation   Pos           Squad                Comp  \
# 0  Patrick van Aanholt  nl NED    DF  Crystal Palace  eng Premier League
# 1          Issah Abbas  gh GHA    FW        Mainz 05       de Bundesliga
# 2     Yunis Abdelhamid  ma MAR    DF           Reims          fr Ligue 1
# 3          Mehdi Abeid  dz ALG  MFDF          Nantes          fr Ligue 1
# 4      Laurent Abergel  fr FRA    MF         Lorient          fr Ligue 1
#
# 0     Age  Born  90s   Cmp   Att  ...  Cmp% Ast    xA   A-xA    KP   1/3  \
# 0  30-089  1990  3.2  45.6  56.3  ...    60   0  0.06  -0.06  0.63  3.75
# 1  22-061  1998    0     2     2  ...   100   0     0      0     0     0
# 2  33-059  1987   10  47.6  53.6  ...    75   0     0      0     0   2.5
# 3  28-112  1992  6.9  40.3  49.1  ...  66.3   0  0.07  -0.07   1.3  4.64
# 4  27-299  1993   10  41.4  49.5  ...  71.8   0  0.02  -0.02   0.2   3.3
#
# 0   PPA CrsPA PrgDist Car  Prog
# 0  1.88  0.31       135.3  6.56
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
clean_data.hist(bins=50, figsize=(20,15))
# save_fig("attribute_histogram_plots")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-23f79044738d> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pyplot as plt
# ----> 3 clean_data.hist(bins=50, figsize=(20,15))
#       4 # save_fig("attribute_histogram_plots")
#       5 plt.show()
#
# c:\users\david\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2403     fig, axes = _subplots(naxes=naxes, ax=ax, squeeze=False,
#    2404                           sharex=sharex, sharey=sharey, figsize=figsize,
# -> 2405                           layout=layout)
#    2406     _axes = _flatten(axes)
#    2407
#
# ...
